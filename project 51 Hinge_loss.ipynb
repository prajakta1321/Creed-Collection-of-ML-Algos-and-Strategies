# %%
import pandas as pd

df = pd.read_csv("hair_loss.csv")

df.head(4)
# Out:
#    total_protein  total_keratine  hair_texture  vitamin  manganese  iron  \
# 0            312             100            14      249         87    55
# 1             52             207             3      425        387     1
# 2            170             197            11      140        199    91
# 3            256             334            19      358        120     3
#
#    calcium  body_water_content  stress_level  liver_data  hair_fall
# 0      333                  44            41         368          4
# 1      182                  26            65          41          1
# 2      414                  30            54          90          4
# 3       35                  48            45          65          2

# %%
X = df[['stress_level','body_water_content','liver_data']]
y = df[['hair_fall']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=22)

# %%
from sklearn import svm
from sklearn.metrics import hinge_loss
from sklearn.datasets import make_classification

# Create a simple binary classification dataset
X, y = make_classification(n_samples=1000, n_features=4, random_state=42)

# Train a LinearSVC model
model = svm.LinearSVC()
model.fit(X, y)

# Make predictions
predictions = model.decision_function(X)

# Calculate the hinge loss
loss = hinge_loss(y, predictions)

print(loss)
# Out:
# 0.4529308569274797
