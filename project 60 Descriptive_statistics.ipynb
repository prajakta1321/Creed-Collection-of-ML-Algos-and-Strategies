# %%
import pandas as pd
import numpy as np
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.value_counts('region')
# Out:
# region
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# dtype: int64

# %%
df['sex'] = df['sex'].replace({'female':1,'male':2,'other':0})
df['smoker'] = df['smoker'].replace({'yes':2,'no':1,'other':0})
df['region'] = df['region'].replace({'southeast':1,'southwest':2,'northwest':3,'northeast':4,'other':0})
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       2       2  16884.92400
# 1      18    2  33.770         1       1       1   1725.55230
# 2      28    2  33.000         3       1       1   4449.46200
# 3      33    2  22.705         0       1       3  21984.47061
# 4      32    2  28.880         0       1       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    2  30.970         3       1       3  10600.54830
# 1334   18    1  31.920         0       1       4   2205.98080
# 1335   18    1  36.850         0       1       1   1629.83350
# 1336   21    1  25.800         0       1       2   2007.94500
# 1337   61    1  29.070         0       2       3  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     1.505232    30.663397     1.094918     1.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     1.000000    15.960000     0.000000     1.000000
# 25%      27.000000     1.000000    26.296250     0.000000     1.000000
# 50%      39.000000     2.000000    30.400000     1.000000     1.000000
# 75%      51.000000     2.000000    34.693750     2.000000     1.000000
# max      64.000000     2.000000    53.130000     5.000000     2.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      2.455157  13270.422265
# std       1.130197  12110.011237
# min       1.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       3.000000  16639.912515
# max       4.000000  63770.428010

# %%
np.mean(df, axis=0)
# Out:
# age            39.207025
# sex             1.505232
# bmi            30.663397
# children        1.094918
# smoker          1.204783
# region          2.455157
# charges     13270.422265
# dtype: float64

# %%
np.median(df, axis=0)
# Out:
# array([3.900000e+01, 2.000000e+00, 3.040000e+01, 1.000000e+00,
#        1.000000e+00, 2.000000e+00, 9.382033e+03])

# %%
np.std(df, axis=0)
# Out:
# age            14.044709
# sex             0.499973
# bmi             6.095908
# children        1.205042
# smoker          0.403543
# region          1.129774
# charges     12105.484976
# dtype: float64

# %%
np.var(df, axis=0)
# Out:
# age         1.972539e+02
# sex         2.499726e-01
# bmi         3.716009e+01
# children    1.452127e+00
# smoker      1.628471e-01
# region      1.276390e+00
# charges     1.465428e+08
# dtype: float64
